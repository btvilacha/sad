# %% [markdown]
# # Primeiro exercício de DataScience
#
# Importar bibliotecas

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
% matplotlib inline
plt.style.use('ggplot')

# %%
# Road in data into a dataframe
df = pd.read_csv('GlobalTemperatures.csv')

# Show the first 10 rows of the table -- tail mostra as 10 ultimas
df.head(10)
# Out:
#            dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0  1750-01-01                   3.034                              3.574
# 1  1750-02-01                   3.083                              3.702
# 2  1750-03-01                   5.626                              3.076
# 3  1750-04-01                   8.490                              2.451
# 4  1750-05-01                  11.573                              2.072
# 5  1750-06-01                  12.937                              1.724
# 6  1750-07-01                  15.868                              1.911
# 7  1750-08-01                  14.750                              2.231
# 8  1750-09-01                  11.413                              2.637
# 9  1750-10-01                   6.367                              2.668
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                 NaN                            NaN                 NaN
# ...

# %%
# Let's just consider the LandAverageTemperature
# "A primary label-location based indexer" -- [lin,col] mostra todas as linhas e as duas primeiras colunas
df = df.ix[:,:2]
df.head(10)
# Out:
#            dt  LandAverageTemperature
# 0  1750-01-01                   3.034
# 1  1750-02-01                   3.083
# 2  1750-03-01                   5.626
# 3  1750-04-01                   8.490
# 4  1750-05-01                  11.573
# 5  1750-06-01                  12.937
# 6  1750-07-01                  15.868
# 7  1750-08-01                  14.750
# 8  1750-09-01                  11.413
# 9  1750-10-01                   6.367

# %%
# Cursory plot
plt.figure(figsize = (15,5))
plt.scatter(x = df['LandAverageTemperature'].index, y = df['LandAverageTemperature'])
plt.title("Temperatura Média da Terra (1750-2015)")
plt.xlabel("Ano")
plt.ylabel("Temperatura média da Terra")
plt.show()
