# %%
import pandas as pd
import numpy as np

# %%
# Create a series
pd.Series(np.random.randn(5), index=['a', 'b', 'c', 'd', 'e'])
# Out:
# a    1.162176
# b    2.210368
# c    0.332007
# d    0.338614
# e   -0.323704
# dtype: float64

# %%
# Preserve the series in variable s for later access
s = pd.Series(np.random.randn(5), index=['a', 'b', 'c', 'd', 'e'])
print(s)
# Out:
# a    0.563585
# b   -0.691963
# c    0.155136
# d   -0.121387
# e    1.983102
# dtype: float64

# %%
# Index
print (s[0])
print("\n")
print (s[:3])
# Out:
# 0.5635846850563029
#
#
# a    0.563585
# b   -0.691963
# c    0.155136
# dtype: float64

# %%
# Create a dataframe
df = pd.DataFrame(s, columns = ['Coluna 1'])
df
# Out:
#    Coluna 1
# a  0.563585
# b -0.691963
# c  0.155136
# d -0.121387
# e  1.983102

# %%
# Can access columns by name
df['Coluna 1']
# Out:
# a    0.563585
# b   -0.691963
# c    0.155136
# d   -0.121387
# e    1.983102
# Name: Coluna 1, dtype: float64

# %%
# Easy to add columns
df['Coluna 2'] = df['Coluna 1'] * 4
df
# Out:
#    Coluna 1  Coluna 2
# a  0.563585  2.254339
# b -0.691963 -2.767851
# c  0.155136  0.620545
# d -0.121387 -0.485549
# e  1.983102  7.932407

# %%
# Other manipulation, like sorting -- if you want to preserve, set equal to a var
df.sort_values(by = 'Coluna 2')
# Out:
#    Coluna 1  Coluna 2
# b -0.691963 -2.767851
# d -0.121387 -0.485549
# c  0.155136  0.620545
# a  0.563585  2.254339
# e  1.983102  7.932407

# %%
# Boolean indexing
df[df['Coluna 2'] <= 2]
# Out:
#    Coluna 1  Coluna 2
# b -0.691963 -2.767851
# c  0.155136  0.620545
# d -0.121387 -0.485549

# %%
df.apply(lambda x: min(x) + max(x))
np.mean(df)
# Out:
# Coluna 1    0.377695
# Coluna 2    1.510778
# dtype: float64

# %%
table = df.describe()
table
# Out:
#        Coluna 1  Coluna 2
# count  5.000000  5.000000
# mean   0.377695  1.510778
# std    1.006810  4.027242
# min   -0.691963 -2.767851
# 25%   -0.121387 -0.485549
# 50%    0.155136  0.620545
# 75%    0.563585  2.254339
# max    1.983102  7.932407

# %%
import matplotlib.pyplot as plt
% matplotlib inline
plt.style.use('ggplot')

# %%
#@title Default title text
# Read in data into a dataframe
df = pd.read_csv(r'C:\Users\beatr\OneDrive\Documentos\SAD\GlobalTemperatures.csv')

# Show the first 5 rows of the table
df.head(10)
# Out:
#            dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0  1750-01-01                   3.034                              3.574
# 1  1750-02-01                   3.083                              3.702
# 2  1750-03-01                   5.626                              3.076
# 3  1750-04-01                   8.490                              2.451
# 4  1750-05-01                  11.573                              2.072
# 5  1750-06-01                  12.937                              1.724
# 6  1750-07-01                  15.868                              1.911
# 7  1750-08-01                  14.750                              2.231
# 8  1750-09-01                  11.413                              2.637
# 9  1750-10-01                   6.367                              2.668
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                 NaN                            NaN                 NaN
# 1                 NaN                            NaN                 NaN
# 2                 NaN                            NaN                 NaN
# 3                 NaN                            NaN                 NaN
# 4                 NaN                            NaN                 NaN
# 5                 NaN                            NaN                 NaN
# 6                 NaN                            NaN                 NaN
# 7                 NaN                            NaN                 NaN
# 8                 NaN                            NaN                 NaN
# 9                 NaN                            NaN                 NaN
#
#    LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
# 5                            NaN                             NaN
# 6                            NaN                             NaN
# 7                            NaN                             NaN
# 8                            NaN                             NaN
# 9                            NaN                             NaN
#
#    LandAndOceanAverageTemperatureUncertainty
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN

# %%
# Let's just consider the LandAverageTemperature
# "A primarily label-location based indexer"
df = df.iloc[:,:2]
df.head(10)
# Out:
#            dt  LandAverageTemperature
# 0  1750-01-01                   3.034
# 1  1750-02-01                   3.083
# 2  1750-03-01                   5.626
# 3  1750-04-01                   8.490
# 4  1750-05-01                  11.573
# 5  1750-06-01                  12.937
# 6  1750-07-01                  15.868
# 7  1750-08-01                  14.750
# 8  1750-09-01                  11.413
# 9  1750-10-01                   6.367

# %%
df.describe()
# Out:
#        LandAverageTemperature
# count             3180.000000
# mean                 8.374731
# std                  4.381310
# min                 -2.080000
# 25%                  4.312000
# 50%                  8.610500
# 75%                 12.548250
# max                 19.021000

# %%
# Cursory plot
plt.figure(figsize = (15, 5))
plt.scatter(x = df['LandAverageTemperature'].index, y = df['LandAverageTemperature'])
plt.title("Temperatura Média da Terra (1750-2015)")
plt.xlabel("Ano")
plt.ylabel("Temperatura media da Terra")
# Out:
# Text(0,0.5,'Temperatura media da Terra')

# %%
# Cursory plot
plt.figure(figsize = (15, 5))
plt.scatter(x = df['LandAverageTemperature'].index, y = df['LandAverageTemperature'])
plt.title("Temperatura Média da Terra (1750-2015)")
plt.xlabel("Ano")
plt.ylabel("Temperatura media da Terra")
plt.show()

# %%
# Maybe we can try only by year?
# But notice that the dt column is made up of strings
print(type(df['dt'][0]))
# Out:
# <class 'str'>

# %%
# Convert to datetime object
times = pd.DatetimeIndex(df['dt'])

# Group by year
grouped = df.groupby([times.year]).mean()

# %%
# Plot
plt.figure(figsize = (15, 5))
plt.plot(grouped['LandAverageTemperature'])

# Change features of the graph
plt.title("Media da temperatura da Terra 1750-2015")
plt.xlabel("Year")
plt.ylabel("Yearly Average Land Temperature")
plt.show()

# %%
# What caused those anomalies?
grouped.head()
# Out:
#       LandAverageTemperature
# dt
# 1750                8.719364
# 1751                7.976143
# 1752                5.779833
# 1753                8.388083
# 1754                8.469333

# %%
# Check what happened in 1752
df[times.year == 1752]
# Out:
#             dt  LandAverageTemperature
# 24  1752-01-01                   0.348
# 25  1752-02-01                     NaN
# 26  1752-03-01                   5.806
# 27  1752-04-01                   8.265
# 28  1752-05-01                     NaN
# 29  1752-06-01                     NaN
# 30  1752-07-01                     NaN
# 31  1752-08-01                     NaN
# 32  1752-09-01                     NaN
# 33  1752-10-01                   7.839
# 34  1752-11-01                   7.335
# 35  1752-12-01                   5.086

# %%
# There are a lot of null values! What else?
df[np.isnan(df['LandAverageTemperature'])]
# Out:
#             dt  LandAverageTemperature
# 10  1750-11-01                     NaN
# 16  1751-05-01                     NaN
# 18  1751-07-01                     NaN
# 21  1751-10-01                     NaN
# 22  1751-11-01                     NaN
# 23  1751-12-01                     NaN
# 25  1752-02-01                     NaN
# 28  1752-05-01                     NaN
# 29  1752-06-01                     NaN
# 30  1752-07-01                     NaN
# 31  1752-08-01                     NaN
# 32  1752-09-01                     NaN

# %%
# Use previous valid observation to fill gap
df['LandAverageTemperature'] = df['LandAverageTemperature'].fillna(method='ffill')

# %%
# Regroup and plot
grouped = df.groupby([times.year]).mean()

# Better, but still not perfect
# What are some other ways to fill the NaN values?
plt.figure(figsize = (15, 5))
plt.plot(grouped['LandAverageTemperature'])
plt.show()

# %%
# Let's model!
from sklearn.linear_model import LinearRegression as LinReg

# %%
x = grouped.index.values.reshape(-1, 1)
y = grouped['LandAverageTemperature'].values

# %%
reg = LinReg()
reg.fit(x, y)
y_preds = reg.predict(x)
print("Accuracy: " + str(reg.score(x, y)))
# Out:
# Accuracy: 0.37668322753090727

# %%
plt.figure(figsize = (15, 5))
plt.title("Linear Regression")
plt.scatter(x = x, y = y_preds)
plt.scatter(x = x, y = y, c = "b")

# %%
reg.predict(2000)
# Out:
# array([8.91609041])
